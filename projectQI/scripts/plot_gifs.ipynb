# %% [markdown]
# ### Create GIF

# %%
import os
import re
# import imageio
import imageio.v2 as imageio

# Define the directory and regex pattern
directory = r'E:\Scripts\project_QI\outputfiles\figures\below_10000'
pattern = re.compile(r'^temporalPerCapByState__below_\d{4}\.png$')  # Example pattern: file_001.txt, file_002.txt, etc.

# List and filter files
png_files = [f for f in os.listdir(directory) if pattern.match(f)]
# List of image file paths
images = []

# Process the matching files
for file_name in png_files:
    filename = os.path.join(directory, file_name)
    images.append(imageio.imread(filename))

# Save as GIF
imageio.mimsave(r'E:\Scripts\project_QI\outputfiles\figures\below_10000\below_10000.gif', images, fps=2, loop=0)
png_files
# Out:
# ['temporalPerCapByState__below_2020.png',
#  'temporalPerCapByState__below_2030.png',
#  'temporalPerCapByState__below_2040.png',
#  'temporalPerCapByState__below_2050.png',
#  'temporalPerCapByState__below_2060.png',
#  'temporalPerCapByState__below_2070.png',
#  'temporalPerCapByState__below_2080.png',
#  'temporalPerCapByState__below_2090.png',
#  'temporalPerCapByState__below_2100.png']

# %%
# Define the directory and regex pattern
directory = r'E:\Scripts\project_QI\outputfiles\figures\above_10000'
pattern = re.compile(r'^temporalPerCapByState__above_\d{4}\.png$')  # Example pattern: file_001.txt, file_002.txt, etc.

# List and filter files
png_files = [f for f in os.listdir(directory) if pattern.match(f)]

# List of image file paths
images = []
# Process the matching files
for file_name in png_files:
    filename = os.path.join(directory, file_name)
    images.append(imageio.imread(filename))

# Save as GIF
imageio.mimsave(r'E:\Scripts\project_QI\outputfiles\figures\above_10000\above_10000.gif', images, fps=2,loop=0)
png_files
# Out:
# ['temporalPerCapByState__above_2020.png',
#  'temporalPerCapByState__above_2030.png',
#  'temporalPerCapByState__above_2040.png',
#  'temporalPerCapByState__above_2050.png',
#  'temporalPerCapByState__above_2060.png',
#  'temporalPerCapByState__above_2070.png',
#  'temporalPerCapByState__above_2080.png',
#  'temporalPerCapByState__above_2090.png',
#  'temporalPerCapByState__above_2100.png']
